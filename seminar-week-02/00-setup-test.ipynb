# %% [markdown]
# # Seminar Notebook 1.0: Is your computer set up for MY459?
#
# **LSE MY459: Computational Text Analysis and Large Language Models** (WT 2026)
#
# **Ryan Hübert**
#
# This notebook allows you to test whether your computer is set up correctly. **Note: we are agnostic about your exact Python and software set up. As long as you can execute the code cells in the last section of this notebook, you will be fine!**

# %% [markdown]
# ## Installation
#
# If you followed the instructions on Moodle, you should have installed [Visual Studio Code](https://code.visualstudio.com/), and the [Miniconda](https://www.anaconda.com/docs/getting-started/miniconda/main) Python distribution.
#
# You can test whether you have installed Miniconda by running the following commands in your computer's terminal. If you are using MacOS, you should open the Terminal app and if you are using Windows, you should open the Powershell app. Then run this line:

# %%
conda init
# Out:
# no change     C:\Users\shuyi\anaconda3\Scripts\conda.exe
# no change     C:\Users\shuyi\anaconda3\Scripts\conda-env.exe
# no change     C:\Users\shuyi\anaconda3\Scripts\conda-script.py
# no change     C:\Users\shuyi\anaconda3\Scripts\conda-env-script.py
# no change     C:\Users\shuyi\anaconda3\condabin\conda.bat
# no change     C:\Users\shuyi\anaconda3\Library\bin\conda.bat
# no change     C:\Users\shuyi\anaconda3\condabin\_conda_activate.bat
# no change     C:\Users\shuyi\anaconda3\condabin\rename_tmp.bat
# no change     C:\Users\shuyi\anaconda3\condabin\conda_auto_activate.bat
# no change     C:\Users\shuyi\anaconda3\condabin\conda_hook.bat
# no change     C:\Users\shuyi\anaconda3\Scripts\activate.bat
# no change     C:\Users\shuyi\anaconda3\condabin\activate.bat
# no change     C:\Users\shuyi\anaconda3\condabin\deactivate.bat
# no change     C:\Users\shuyi\anaconda3\Scripts\activate
# no change     C:\Users\shuyi\anaconda3\Scripts\deactivate
# ...

# %%
conda --version
# Out:
# conda 25.5.1
#
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# You should see something like `conda 25.x.x`. Then, you should try to activate conda by using the following command:

# %%
conda activate
# Out:
# Note: you may need to restart the kernel to use updated packages.
# CondaError: Run 'conda init' before 'conda activate'

# %% [markdown]
# You will then see something like `(base)` written inside your command line prompt. Note: if you see `(base)` written inside your command line prompt without typing `conda activate`, then miniconda is installed and working on your computer. You should follow any instructions provided in the document on Moodle, but we also recommend that you create a specific miniconda environment for coursework in this course. You can name it whatever you want, for example `lse-my459`. To create it, use the following command in the terminal, setting the Python version to 3.12 (or whatever version you prefer, if you have a preference).

# %%
conda create -n lse-my459 python=3.12
# Out:
# ^C
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda create -n lse-my459 python=3.12 --solver=libmamba
# Out:
# ^C
#
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# To activate this specific conda environment in the terminal, you use:

# %%
conda activate lse-my459

# %% [markdown]
# If successful, you will see `(lse-my459)` (or whatever name you chose) in the command line prompt.

# %% [markdown]
# ## Opening files
#
# To work effectively with VS Code, you need to break your habit of opening individual files by double clicking on them inside your computer's file browser ("Finder" on MacOS and "File Explorer" on Windows). This is because VS Code wants you to treat your folders like "projects" that the app recognises and assigns settings to. This is partly for security reasons, and partly because most programmers organise their work into directories such as Git/GitHub repos, etc.
#
# When you are ready to work with Python-based files in this course, you should open VS Code and then inside the app, open the folder containing the files you want to work with. The contents of the folder you open should appear on the left panel inside VS Code.

# %% [markdown]
# ## Connecting to a kernel
#
# When you open a Jupyter notebook (`.ipynb`), you will need to connect it to a kernel using the button on the top right of the notebook. If you created a specific environment for this course (such as `lse-my459`), then you should connect to that kernel. **Please be sure to get this working before seminar, as we will only be able to provide limited technical support for general Python issues, including installation and connecting to kernels.**

# %% [markdown]
# ## Testing that you can execute Python code cells
#
# Once you have connected to a kernel, then you should try to execute the following Python code cells.

# %%
my_string = "I love MY459!"
my_string = my_string.replace("love", "like")
print(my_string)
# Out:
# I like MY459!

# %% [markdown]
# In the next code chunk you will import several modules we will use in the course. If you are unable to import them, then you should install them in the conda environment you are using for this course (see below).

# %%
import pandas as pd
import numpy as np
import wordcloud
import nltk
import sklearn
import scipy

# %% [markdown]
# ## Installing modules
#
# If you need to install any of these modules, you can do the following (assuming you are using the miniconda distribution we suggested).
#
# 1. Navigate to the integrated terminal inside VS Code, which should appear as an option in the bottom panel. Alternatively, you can open a new terminal window by using the "New Terminal" option in the "Terminal" menu.
# 2. Ensure that the conda environment you use in this course is activated. If you made a specific one for the class, you should see `(lse-my459)` in the prompt (or whatever you call your environment). If you are just using the default conda environment you should see `(base)` in the prompt. If you do not see either, then you need to activate your environment as stated above, e.g. `conda activate lse-my459` for a specific named environment, or `conda activate` for the default environment.
# 3. Use one of the following (**but not both**!):
#    1. Type `conda install` and then list the packages you want to install, such as `conda install numpy pandas`
#    2. Type `pip install` and then list the packages you want to install, such as `pip install numpy pandas`
#
# Ryan always uses `pip install` to install packages in his conda environments, but conda recommends using `conda install`.
